# %% [markdown]
# <a href="https://colab.research.google.com/github/withjiran/withjiran/blob/main/colabLearning.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Out:
# Files already downloaded and verified
# Files already downloaded and verified
# 训练集大小为：50000
# 测试集大小为：10000
# 第1轮训练开始
# 第1轮的测试集准确率为0.19655999541282654
# 第1轮的训练集准总损失为1687.572534441948
# ...
# 第1轮的测试集准确率为0.31209999322891235
# 第1轮的测试集准总损失为306.1794738769531
# ***************
# 第2轮训练开始
# 第2轮的测试集准确率为0.34779998660087585
# 第2轮的训练集准总损失为1437.956372976303
# ...
# 第2轮的测试集准确率为0.3781000077724457
# 第2轮的测试集准总损失为271.8828430175781
# ***************
# 第3轮训练开始
# 第3轮的测试集准确率为0.41308000683784485
# 第3轮的训练集准总损失为1292.6397268772125
# ...
# 第3轮的测试集准确率为0.42829999327659607
# 第3轮的测试集准总损失为249.58206176757812
# ***************
# 第4轮训练开始
# 第4轮的测试集准确率为0.45482000708580017
# 第4轮的训练集准总损失为1198.9730927944183
# ...
# 第4轮的测试集准确率为0.44780001044273376
# 第4轮的测试集准总损失为248.5248565673828
# ***************
# 第5轮训练开始
# 第5轮的测试集准确率为0.4857800006866455
# 第5轮的训练集准总损失为1131.4568548202515
# ...
# 第5轮的测试集准确率为0.4350000023841858
# 第5轮的测试集准总损失为241.92730712890625
# ***************
# 第6轮训练开始
# 第6轮的测试集准确率为0.5134400129318237
# 第6轮的训练集准总损失为1078.2850852012634
# ...
